# %%
#DATA WRANGLING

# %%
#Code task 1#
#Import pandas, matplotlib.pyplot

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import os

#from library.sb_utils import save_file

# %%
#Loading data
# the supplied CSV data/accepted_2007_to_2018q4 file is the  directory
accept_data = pd.read_csv('../data/accepted_2007_to_2018q4/accepted_2007_to_2018Q4.csv')

# %%
accept_data.info
# Out:
# <bound method DataFrame.info of                                                        id  member_id  \
# 0                                                68407277        NaN
# 1                                                68355089        NaN
# 2                                                68341763        NaN
# 3                                                66310712        NaN
# 4                                                68476807        NaN
# ...                                                   ...        ...
# 2260696                                          88985880        NaN
# 2260697                                          88224441        NaN
# 2260698                                          88215728        NaN
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# ...

# %%
accept_data.shape
# Out:
# (2260701, 151)

# %%
accept_data.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# ...

# %%
accept_data.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=151)

# %%
accept_data.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
# ...

# %%
#The output above displayed that there are a missing value in some columns
#Count the number of missing values in each column and sort them.

# %%
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#accept_data as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([accept_data.isnull().sum(), 100 * accept_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                                               count           %
# member_id                                   2260701  100.000000
# orig_projected_additional_accrued_interest  2252050   99.617331
# hardship_end_date                           2249784   99.517097
# hardship_start_date                         2249784   99.517097
# hardship_type                               2249784   99.517097
# ...                                             ...         ...
# policy_code                                      33    0.001460
# revol_bal                                        33    0.001460
# fico_range_high                                  33    0.001460
# fico_range_low                                   33    0.001460
# id                                                0    0.000000
#
# [151 rows x 2 columns]

# %%
pct_null = accept_data.isnull().sum() / len(accept_data)
pct_null = pct_null[pct_null > 0.80]
missing_feature_80pct = pct_null.index
missing_feature_80pct
# Out:
# Index(['member_id', 'desc', 'mths_since_last_record', 'annual_inc_joint',
#        'dti_joint', 'verification_status_joint', 'revol_bal_joint',
#        'sec_app_fico_range_low', 'sec_app_fico_range_high',
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_act_il', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'deferral_term',
#        'hardship_amount', 'hardship_start_date', 'hardship_end_date',
#        'payment_plan_start_date', 'hardship_length', 'hardship_dpd',
#        'hardship_loan_status', 'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
# ...

# %%
len(missing_feature_80pct)
# Out:
# 39

# %%
clean_data = accept_data.drop(missing_feature_80pct, axis=1)
clean_data.shape
# Out:
# (2260701, 112)

# %%
clean_data.info
# Out:
# <bound method DataFrame.info of                                                        id  loan_amnt  \
# 0                                                68407277     3600.0
# 1                                                68355089    24700.0
# 2                                                68341763    20000.0
# 3                                                66310712    35000.0
# 4                                                68476807    10400.0
# ...                                                   ...        ...
# 2260696                                          88985880    40000.0
# 2260697                                          88224441    24000.0
# 2260698                                          88215728    14000.0
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# ...

# %%
clean_data.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title',
#        ...
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit', 'hardship_flag', 'disbursement_method',
#        'debt_settlement_flag'],
#       dtype='object', length=112)

# %%
clean_data.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean   1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std    9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min    5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%    8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%    1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%    2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max    4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# std    2.671735e+02  1.126962e+05  1.418333e+01  8.672303e-01    3.301038e+01
# ...

# %%
clean_data.dtypes
# Out:
# id                             object
# loan_amnt                     float64
# funded_amnt                   float64
# funded_amnt_inv               float64
# term                           object
#                                ...
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# hardship_flag                  object
# disbursement_method            object
# debt_settlement_flag           object
# Length: 112, dtype: object

# %%
clean_data.select_dtypes(exclude=np.number)
# Out:
#                                                        id        term grade  \
# 0                                                68407277   36 months     C
# 1                                                68355089   36 months     C
# 2                                                68341763   60 months     B
# 3                                                66310712   60 months     C
# 4                                                68476807   60 months     F
# ...                                                   ...         ...   ...
# 2260696                                          88985880   60 months     B
# 2260697                                          88224441   60 months     C
# 2260698                                          88215728   60 months     C
# 2260699  Total amount funded in policy code 1: 1465324575         NaN   NaN
# 2260700   Total amount funded in policy code 2: 521953170         NaN   NaN
#
# ...

# %%
print(clean_data['application_type'].unique())
# Out:
# ['Individual' 'Joint App' nan]

# %%
print((clean_data['application_type'] == 'Individual').sum()/len(clean_data))
# Out:
# 0.9465904602156587

# %%
print((clean_data['application_type'] == 'Joint App').sum()/len(clean_data))
# Out:
# 0.05339494254215838

# %%
#We have about 95% indivisual loans and 0.5% joint. There is an identical data in this column
# we can get rid of it

# %%
clean_data.drop('application_type', axis=1, inplace=True)

# %%
print(clean_data['disbursement_method'].unique())
# Out:
# ['Cash' nan 'DirectPay']

# %%
print((clean_data['disbursement_method'] == 'Cash').sum()/len(clean_data))
# Out:
# 0.9654288647636287

# %%
print((clean_data['disbursement_method'] == 'DirectPay').sum()/len(clean_data))
# Out:
# 0.03455653799418853

# %%
print(clean_data['emp_title'].unique()
# Out:
# ['leadman' 'Engineer' 'truck driver' ... 'Sr. Photo Producer'
#  'Exec Dir Internal Audit' 'Current Operations Officer']

# %%
print(clean_data['url'].unique())
# Out:
# ['https://lendingclub.com/browse/loanDetail.action?loan_id=68407277'
#  'https://lendingclub.com/browse/loanDetail.action?loan_id=68355089'
#  'https://lendingclub.com/browse/loanDetail.action?loan_id=68341763' ...
#  'https://lendingclub.com/browse/loanDetail.action?loan_id=88985880'
#  'https://lendingclub.com/browse/loanDetail.action?loan_id=88224441'
#  'https://lendingclub.com/browse/loanDetail.action?loan_id=88215728']

# %%
len(clean_data['url'].unique())
# Out:
# 2260669

# %%
# There is no valueable information we can use for analysis in 
# disbursement_method , emp_title, url columns. We can drop them

# %%
clean_data.drop(['url', 'disbursement_method', 'emp_title'], axis=1, inplace=True)

# %%
clean_data.shape
# Out:
# (2260701, 108)
